# %%
from src.OCR.data.RNG import  RandomTextGenerator, RandomTextImageGenerator

text_rng = RandomTextGenerator()
img_rng_gen = RandomTextImageGenerator((800, 128), text_rng)()

# %%
next(img_rng_gen)
# Out:
# (128, 800, 3)
# <PIL.Image.Image image mode=RGB size=800x128 at 0x7F08384CAD00>

# %%
next(img_rng_gen)
# Out:
# <PIL.Image.Image image mode=RGB size=800x128 at 0x7F082801CB80>

# %%
next(img_rng_gen)
# Out:
# <PIL.Image.Image image mode=RGB size=800x128 at 0x7F08384CAD30>

# %%
next(img_rng_gen)
# Out:
# <PIL.Image.Image image mode=RGB size=800x128 at 0x7F081C631BB0>

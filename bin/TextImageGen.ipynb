# %%
from src.OCR.data.IO import read_languages
from src.OCR.data.RNG import RandomTextGenerator, RandomTextImageGenerator

size = (800, 128)

languages = read_languages()
text_rng = RandomTextGenerator(languages, size[1])
img_rng_gen = RandomTextImageGenerator(size, text_rng)()

# %%
next(img_rng_gen).img
# Out:
# <PIL.Image.Image image mode=RGB size=800x128 at 0x7FF8AC427490>

# %%
next(img_rng_gen).img
# Out:
# <PIL.Image.Image image mode=RGB size=800x128 at 0x7FF8AC41B100>

# %%
next(img_rng_gen).img
# Out:
# <PIL.Image.Image image mode=RGB size=800x128 at 0x7FF89CB32D90>

# %%
next(img_rng_gen).img
# Out:
# <PIL.Image.Image image mode=RGB size=800x128 at 0x7FF8AC42C670>
